# %%
import pandas as pd

# Load the data
df = pd.read_csv("household_data.csv")

# create sub dataframes filtered by column
issue = {
    'water': (df.filter(regex='.*wat.*|iso3|year', axis=1), 'Water', 'Blues'),
    'sanitation': (df.filter(regex='.*san.*|iso3|year', axis=1), 'Sanitation', 'Greens'),
    'hygiene': (df.filter(regex='.*hyg.*|iso3|year', axis=1), 'Hygiene', 'Yellows')
}
issue['hygiene'][0].dropna()
# Out:
#      iso3  year  hyg_bas_n  hyg_lim_n  hyg_nfac_n  arc_hyg_bas_n  hyg_bas_r  \
# 15    AFG  2015  37.692803  34.412268   27.894928       0.084449  29.129445
# 16    AFG  2016  37.767724  34.379108   27.853168       0.084449  29.129445
# 17    AFG  2017  37.847132  34.343962   27.808907       0.084449  29.129445
# 18    AFG  2018  37.931720  34.306525   27.761755       0.084449  29.129445
# 19    AFG  2019  38.021140  34.266947   27.711914       0.084449  29.129445
# ...   ...   ...        ...        ...         ...            ...        ...
# 4909  ZWE  2016  42.436694  54.625722    2.937584      -0.005605  36.107244
# 4910  ZWE  2017  42.425130  54.636305    2.938565      -0.005605  36.107244
# 4911  ZWE  2018  42.419642  54.641329    2.939029      -0.005605  36.107244
# 4912  ZWE  2019  42.419840  54.641151    2.939009      -0.005605  36.107244
# 4913  ZWE  2020  42.426111  54.635410    2.938479      -0.005605  36.107244
#
# ...

# %%
df.columns
# Out:
# Index(['country', 'iso3', 'region', 'year', 'pop', 'pop_urban', 'wat_bas_n',
#        'wat_lim_n', 'wat_unimp_n', 'wat_sur_n', 'arc_wat_bas_n', 'wat_bas_r',
#        'wat_lim_r', 'wat_unimp_r', 'wat_sur_r', 'arc_wat_bas_r', 'wat_bas_u',
#        'wat_lim_u', 'wat_unimp_u', 'wat_sur_u', 'arc_wat_bas_u', 'wat_sm_n',
#        'wat_premises_n', 'wat_available_n', 'wat_quality_n', 'arc_wat_sm_n',
#        'wat_pip_n', 'wat_npip_n', 'wat_sm_r', 'wat_premises_r',
#        'wat_available_r', 'wat_quality_r', 'arc_wat_sm_r', 'wat_pip_r',
#        'wat_npip_r', 'wat_sm_u', 'wat_premises_u', 'wat_available_u',
#        'wat_quality_u', 'arc_wat_sm_u', 'wat_pip_u', 'wat_npip_u', 'hyg_bas_n',
#        'hyg_lim_n', 'hyg_nfac_n', 'arc_hyg_bas_n', 'hyg_bas_r', 'hyg_lim_r',
#        'hyg_nfac_r', 'arc_hyg_bas_r', 'hyg_bas_u', 'hyg_lim_u', 'hyg_nfac_u',
#        'arc_hyg_bas_u', 'san_bas_n', 'san_lim_n', 'san_unimp_n', 'san_od_n',
#        'arc_san_bas_n', 'arc_san_od_n', 'san_bas_r', 'san_lim_r',
# ...
