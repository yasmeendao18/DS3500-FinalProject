# %%
import pandas as pd
df = pd.read_csv('household_data.csv')
df.head()
# Out:
#        country iso3                     region  year           pop  \
# 0  Afghanistan  AFG  Central and Southern Asia  2000  2.077996e+07
# 1  Afghanistan  AFG  Central and Southern Asia  2001  2.160699e+07
# 2  Afghanistan  AFG  Central and Southern Asia  2002  2.260077e+07
# 3  Afghanistan  AFG  Central and Southern Asia  2003  2.368087e+07
# 4  Afghanistan  AFG  Central and Southern Asia  2004  2.472669e+07
#
#       pop_urban     wat_bas_n     wat_lim_n   wat_unimp_n     wat_sur_n  ...  \
# 0  4.587799e+06  5.854008e+06  7.606791e+05  8.972433e+06  5.192837e+06  ...
# 1  4.790054e+06  6.093035e+06  7.911491e+05  9.327207e+06  5.395601e+06  ...
# 2  5.031158e+06  6.833657e+06  8.926112e+05  9.422176e+06  5.452329e+06  ...
# 3  5.293385e+06  7.642699e+06  1.003395e+06  9.522299e+06  5.512479e+06  ...
# 4  5.563505e+06  8.488316e+06  1.118861e+06  9.575232e+06  5.544279e+06  ...
#
#        san_sew_r  san_sm_u  san_sdo_sm_u  san_fst_sm_u  san_sew_sm_u  \
# ...
